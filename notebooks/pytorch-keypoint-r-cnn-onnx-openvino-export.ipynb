# %% [markdown]
# ## Setting Up Your Python Environment

# %%
# %%capture
# # Install PyTorch with CUDA
# !pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu118

# # Install additional dependencies
# !pip install pandas pillow

# # Install ONNX packages
# !pip install onnx onnxruntime onnx-simplifier

# # Install OpenVINO
# !pip install openvino

# # Install utility packages
# !pip install cjm_psl_utils cjm_pil_utils

# %% [markdown]
# ## Importing the Required Dependencies

# %%
# Import Python Standard Library dependencies
import json
from pathlib import Path
import random

# Import utility functions
from cjm_psl_utils.core import download_file
from cjm_pil_utils.core import resize_img

# Import numpy
import numpy as np

# Import the pandas package
import pandas as pd

# Import PIL for image manipulation
from PIL import Image, ImageDraw, ImageFont

# Import PyTorch dependencies
import torch

# Import Keypoint R-CNN
from torchvision.models.detection import keypointrcnn_resnet50_fpn
from torchvision.models.detection.keypoint_rcnn import KeypointRCNNPredictor
from torchvision.models.detection.rpn import AnchorGenerator
from torchvision.transforms import functional as F

# Import ONNX dependencies
import onnx # Import the onnx module
from onnxsim import simplify # Import the method to simplify ONNX models
import onnxruntime as ort # Import the ONNX Runtime

# %% [markdown]
# ## Setting Up the Project

# %% [markdown]
# ### Set the Directory Paths

# %%
# The name for the project
project_name = f"pytorch-keypoint-r-cnn"

# The path for the project folder
project_dir = Path(f"./{project_name}/")

# Create the project directory if it does not already exist
project_dir.mkdir(parents=True, exist_ok=True)

# The path to the checkpoint folder
checkpoint_dir = Path(project_dir/f"2024-01-29_14-10-56")

pd.Series({
    "Project Directory:": project_dir,
    "Checkpoint Directory:": checkpoint_dir,
}).to_frame().style.hide(axis='columns')
# Out:
# <style type="text/css">
# </style>
# <table id="T_fd4c9">
#   <thead>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fd4c9_level0_row0" class="row_heading level0 row0" >Project Directory:</th>
#       <td id="T_fd4c9_row0_col0" class="data row0 col0" >pytorch-keypoint-r-cnn</td>
#     </tr>
#     <tr>
#       <th id="T_fd4c9_level0_row1" class="row_heading level0 row1" >Checkpoint Directory:</th>
#       <td id="T_fd4c9_row1_col0" class="data row1 col0" >pytorch-keypoint-r-cnn/2024-01-29_14-10-56</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Download a Font File

# %%
# Set the name of the font file
font_file = 'KFOlCnqEu92Fr1MmEU9vAw.ttf'

# Download the font file
download_file(f"https://fonts.gstatic.com/s/roboto/v30/{font_file}", "./")
# Out:
# The file ./KFOlCnqEu92Fr1MmEU9vAw.ttf already exists and overwrite is set to False.

# %% [markdown]
# ## Loading the Checkpoint Data

# %% [markdown]
# ### Load the Colormap

# %%
# The colormap path
colormap_path = list(checkpoint_dir.glob('*colormap.json'))[0]

# Load the JSON colormap data
with open(colormap_path, 'r') as file:
        colormap_json = json.load(file)

# Convert the JSON data to a dictionary        
colormap_dict = {item['label']: item['color'] for item in colormap_json['items']}

# Extract the class names from the colormap
class_names = list(colormap_dict.keys())

# Make a copy of the colormap in integer format
int_colors = [tuple(int(c*255) for c in color) for color in colormap_dict.values()]

# %% [markdown]
# ### Load the Model Checkpoint

# %%
# The model checkpoint path
checkpoint_path = list(checkpoint_dir.glob('*.pth'))[0]

# Load the model checkpoint onto the CPU
model_checkpoint = torch.load(checkpoint_path, map_location='cpu')

# %% [markdown]
# ### Load the Trained Keypoint R-CNN Model

# %%
# Load a pre-trained model
model = keypointrcnn_resnet50_fpn(weights='DEFAULT')

# Replace the classifier head with the number of keypoints
in_features = model.roi_heads.keypoint_predictor.kps_score_lowres.in_channels
model.roi_heads.keypoint_predictor = KeypointRCNNPredictor(in_channels=in_features, num_keypoints=len(class_names))

# Initialize the model with the checkpoint parameters and buffers
model.load_state_dict(model_checkpoint)
# Out:
# <All keys matched successfully>

# %% [markdown]
# ## Exporting the Model to ONNX

# %%
model.eval();

# %% [markdown]
# ### Prepare the Input Tensor

# %%
input_tensor = torch.randn(1, 3, 256, 256)

# %% [markdown]
# ### Export the Model to ONNX

# %%
# Set a filename for the ONNX model
onnx_file_path = f"{checkpoint_dir}/{colormap_path.stem.removesuffix('-colormap')}-{checkpoint_path.stem}.onnx"

# Export the PyTorch model to ONNX format
torch.onnx.export(model.cpu(),
                  input_tensor.cpu(),
                  onnx_file_path,
                  export_params=True,
                  do_constant_folding=False,
                  input_names = ['input'],
                  output_names = ['boxes', 'labels', 'scores', 'masks'],
                  dynamic_axes={'input': {2 : 'height', 3 : 'width'}}
                 )
# Out:
# /home/innom-dt/mambaforge/envs/pytorch-env/lib/python3.11/site-packages/torch/nn/functional.py:3964: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   (torch.floor((input.size(i + 2).float() * torch.tensor(scale_factors[i], dtype=torch.float32)).float()))
# /home/innom-dt/mambaforge/envs/pytorch-env/lib/python3.11/site-packages/torchvision/ops/boxes.py:157: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   boxes_x = torch.min(boxes_x, torch.tensor(width, dtype=boxes.dtype, device=boxes.device))
# /home/innom-dt/mambaforge/envs/pytorch-env/lib/python3.11/site-packages/torchvision/ops/boxes.py:159: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   boxes_y = torch.min(boxes_y, torch.tensor(height, dtype=boxes.dtype, device=boxes.device))
# /home/innom-dt/mambaforge/envs/pytorch-env/lib/python3.11/site-packages/torch/__init__.py:1404: TracerWarning: Converting a tensor to a Python boolean might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   assert condition, message
# /home/innom-dt/mambaforge/envs/pytorch-env/lib/python3.11/site-packages/torchvision/models/detection/transform.py:306: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   torch.tensor(s, dtype=torch.float32, device=boxes.device)
# /home/innom-dt/mambaforge/envs/pytorch-env/lib/python3.11/site-packages/torchvision/models/detection/transform.py:307: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   / torch.tensor(s_orig, dtype=torch.float32, device=boxes.device)
# /home/innom-dt/mambaforge/envs/pytorch-env/lib/python3.11/site-packages/torchvision/models/detection/transform.py:288: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   torch.tensor(s, dtype=torch.float32, device=keypoints.device)
# /home/innom-dt/mambaforge/envs/pytorch-env/lib/python3.11/site-packages/torchvision/models/detection/transform.py:289: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   / torch.tensor(s_orig, dtype=torch.float32, device=keypoints.device)
# /home/innom-dt/mambaforge/envs/pytorch-env/lib/python3.11/site-packages/torch/onnx/symbolic_opset9.py:5857: UserWarning: Exporting aten::index operator of advanced indexing in opset 17 is achieved by combination of multiple ONNX operators, including Reshape, Transpose, Concat, and Gather. If indices include negative values, the exported graph will produce incorrect results.
#   warnings.warn(
# /home/innom-dt/mambaforge/envs/pytorch-env/lib/python3.11/site-packages/torch/onnx/utils.py:1686: UserWarning: The exported ONNX model failed ONNX shape inference. The model will not be executable by the ONNX Runtime. If this is unintended and you believe there is a bug, please report an issue at https://github.com/pytorch/pytorch/issues. Error reported by strict ONNX shape inference: [ShapeInferenceError] Shape inference error(s): (op_type:Resize, node name: /transform/Resize): [ShapeInferenceError] Number of elements of input 'sizes' (0) must be same as rank of input 'X' (4).
# (op_type:Gather, node name: /transform/Gather_2): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Pad, node name: /transform/Pad): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Unsqueeze, node name: /transform/Unsqueeze_22): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Concat, node name: /transform/Concat_8): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Conv, node name: /backbone/body/conv1/Conv): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Mul, node name: /backbone/body/bn1/Mul_2): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Add, node name: /backbone/body/bn1/Add_1): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Relu, node name: /backbone/body/relu/Relu): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:MaxPool, node name: /backbone/body/maxpool/MaxPool): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Conv, node name: /backbone/body/layer1/layer1.0/conv1/Conv): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Mul, node name: /backbone/body/layer1/layer1.0/bn1/Mul_2): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Add, node name: /backbone/body/layer1/layer1.0/bn1/Add_1): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Relu, node name: /backbone/body/layer1/layer1.0/relu/Relu): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Conv, node name: /backbone/body/layer1/layer1.0/conv2/Conv): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Mul, node name: /backbone/body/layer1/layer1.0/bn2/Mul_2): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Add, node name: /backbone/body/layer1/layer1.0/bn2/Add_1): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Relu, node name: /backbone/body/layer1/layer1.0/relu_1/Relu): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Conv, node name: /backbone/body/layer1/layer1.0/conv3/Conv): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Mul, node name: /backbone/body/layer1/layer1.0/bn3/Mul_2): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Add, node name: /backbone/body/layer1/layer1.0/bn3/Add_1): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Conv, node name: /backbone/body/layer1/layer1.0/downsample/downsample.0/Conv): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Mul, node name: /backbone/body/layer1/layer1.0/downsample/downsample.1/Mul_2): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Add, node name: /backbone/body/layer1/layer1.0/downsample/downsample.1/Add_1): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Add, node name: /backbone/body/layer1/layer1.0/Add): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Relu, node name: /backbone/body/layer1/layer1.0/relu_2/Relu): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Conv, node name: /backbone/body/layer1/layer1.1/conv1/Conv): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Mul, node name: /backbone/body/layer1/layer1.1/bn1/Mul_2): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Add, node name: /backbone/body/layer1/layer1.1/bn1/Add_1): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Relu, node name: /backbone/body/layer1/layer1.1/relu/Relu): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Conv, node name: /backbone/body/layer1/layer1.1/conv2/Conv): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Mul, node name: /backbone/body/layer1/layer1.1/bn2/Mul_2): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Add, node name: /backbone/body/layer1/layer1.1/bn2/Add_1): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Relu, node name: /backbone/body/layer1/layer1.1/relu_1/Relu): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Conv, node name: /backbone/body/layer1/layer1.1/conv3/Conv): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Mul, node name: /backbone/body/layer1/layer1.1/bn3/Mul_2): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Add, node name: /backbone/body/layer1/layer1.1/bn3/Add_1): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Add, node name: /backbone/body/layer1/layer1.1/Add): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Relu, node name: /backbone/body/layer1/layer1.1/relu_2/Relu): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Conv, node name: /backbone/body/layer1/layer1.2/conv1/Conv): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Mul, node name: /backbone/body/layer1/layer1.2/bn1/Mul_2): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Add, node name: /backbone/body/layer1/layer1.2/bn1/Add_1): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Relu, node name: /backbone/body/layer1/layer1.2/relu/Relu): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Conv, node name: /backbone/body/layer1/layer1.2/conv2/Conv): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Mul, node name: /backbone/body/layer1/layer1.2/bn2/Mul_2): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Add, node name: /backbone/body/layer1/layer1.2/bn2/Add_1): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Relu, node name: /backbone/body/layer1/layer1.2/relu_1/Relu): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Conv, node name: /backbone/body/layer1/layer1.2/conv3/Conv): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Mul, node name: /backbone/body/layer1/layer1.2/bn3/Mul_2): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Add, node name: /backbone/body/layer1/layer1.2/bn3/Add_1): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Add, node name: /backbone/body/layer1/layer1.2/Add): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Relu, node name: /backbone/body/layer1/layer1.2/relu_2/Relu): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Conv, node name: /backbone/body/layer2/layer2.0/conv1/Conv): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Mul, node name: /backbone/body/layer2/layer2.0/bn1/Mul_2): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Add, node name: /backbone/body/layer2/layer2.0/bn1/Add_1): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Relu, node name: /backbone/body/layer2/layer2.0/relu/Relu): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Conv, node name: /backbone/body/layer2/layer2.0/conv2/Conv): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Mul, node name: /backbone/body/layer2/layer2.0/bn2/Mul_2): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Add, node name: /backbone/body/layer2/layer2.0/bn2/Add_1): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Relu, node name: /backbone/body/layer2/layer2.0/relu_1/Relu): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Conv, node name: /backbone/body/layer2/layer2.0/conv3/Conv): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Mul, node name: /backbone/body/layer2/layer2.0/bn3/Mul_2): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Add, node name: /backbone/body/layer2/layer2.0/bn3/Add_1): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Conv, node name: /backbone/body/layer2/layer2.0/downsample/downsample.0/Conv): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Mul, node name: /backbone/body/layer2/layer2.0/downsample/downsample.1/Mul_2): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Add, node name: /backbone/body/layer2/layer2.0/downsample/downsample.1/Add_1): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Add, node name: /backbone/body/layer2/layer2.0/Add): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Relu, node name: /backbone/body/layer2/layer2.0/relu_2/Relu): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Conv, node name: /backbone/body/layer2/layer2.1/conv1/Conv): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Mul, node name: /backbone/body/layer2/layer2.1/bn1/Mul_2): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Add, node name: /backbone/body/layer2/layer2.1/bn1/Add_1): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Relu, node name: /backbone/body/layer2/layer2.1/relu/Relu): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Conv, node name: /backbone/body/layer2/layer2.1/conv2/Conv): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Mul, node name: /backbone/body/layer2/layer2.1/bn2/Mul_2): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Add, node name: /backbone/body/layer2/layer2.1/bn2/Add_1): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Relu, node name: /backbone/body/layer2/layer2.1/relu_1/Relu): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Conv, node name: /backbone/body/layer2/layer2.1/conv3/Conv): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Mul, node name: /backbone/body/layer2/layer2.1/bn3/Mul_2): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Add, node name: /backbone/body/layer2/layer2.1/bn3/Add_1): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Add, node name: /backbone/body/layer2/layer2.1/Add): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Relu, node name: /backbone/body/layer2/layer2.1/relu_2/Relu): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Conv, node name: /backbone/body/layer2/layer2.2/conv1/Conv): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Mul, node name: /backbone/body/layer2/layer2.2/bn1/Mul_2): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Add, node name: /backbone/body/layer2/layer2.2/bn1/Add_1): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Relu, node name: /backbone/body/layer2/layer2.2/relu/Relu): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Conv, node name: /backbone/body/layer2/layer2.2/conv2/Conv): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Mul, node name: /backbone/body/layer2/layer2.2/bn2/Mul_2): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Add, node name: /backbone/body/layer2/layer2.2/bn2/Add_1): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Relu, node name: /backbone/body/layer2/layer2.2/relu_1/Relu): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Conv, node name: /backbone/body/layer2/layer2.2/conv3/Conv): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Mul, node name: /backbone/body/layer2/layer2.2/bn3/Mul_2): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Add, node name: /backbone/body/layer2/layer2.2/bn3/Add_1): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Add, node name: /backbone/body/layer2/layer2.2/Add): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Relu, node name: /backbone/body/layer2/layer2.2/relu_2/Relu): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Conv, node name: /backbone/body/layer2/layer2.3/conv1/Conv): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Mul, node name: /backbone/body/layer2/layer2.3/bn1/Mul_2): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Add, node name: /backbone/body/layer2/layer2.3/bn1/Add_1): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Relu, node name: /backbone/body/layer2/layer2.3/relu/Relu): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Conv, node name: /backbone/body/layer2/layer2.3/conv2/Conv): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Mul, node name: /backbone/body/layer2/layer2.3/bn2/Mul_2): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Add, node name: /backbone/body/layer2/layer2.3/bn2/Add_1): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Relu, node name: /backbone/body/layer2/layer2.3/relu_1/Relu): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Conv, node name: /backbone/body/layer2/layer2.3/conv3/Conv): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Mul, node name: /backbone/body/layer2/layer2.3/bn3/Mul_2): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Add, node name: /backbone/body/layer2/layer2.3/bn3/Add_1): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Add, node name: /backbone/body/layer2/layer2.3/Add): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Relu, node name: /backbone/body/layer2/layer2.3/relu_2/Relu): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Conv, node name: /backbone/body/layer3/layer3.0/conv1/Conv): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Mul, node name: /backbone/body/layer3/layer3.0/bn1/Mul_2): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Add, node name: /backbone/body/layer3/layer3.0/bn1/Add_1): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Relu, node name: /backbone/body/layer3/layer3.0/relu/Relu): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Conv, node name: /backbone/body/layer3/layer3.0/conv2/Conv): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Mul, node name: /backbone/body/layer3/layer3.0/bn2/Mul_2): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Add, node name: /backbone/body/layer3/layer3.0/bn2/Add_1): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Relu, node name: /backbone/body/layer3/layer3.0/relu_1/Relu): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Conv, node name: /backbone/body/layer3/layer3.0/conv3/Conv): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Mul, node name: /backbone/body/layer3/layer3.0/bn3/Mul_2): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Add, node name: /backbone/body/layer3/layer3.0/bn3/Add_1): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Conv, node name: /backbone/body/layer3/layer3.0/downsample/downsample.0/Conv): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Mul, node name: /backbone/body/layer3/layer3.0/downsample/downsample.1/Mul_2): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Add, node name: /backbone/body/layer3/layer3.0/downsample/downsample.1/Add_1): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Add, node name: /backbone/body/layer3/layer3.0/Add): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Relu, node name: /backbone/body/layer3/layer3.0/relu_2/Relu): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Conv, node name: /backbone/body/layer3/layer3.1/conv1/Conv): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Mul, node name: /backbone/body/layer3/layer3.1/bn1/Mul_2): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Add, node name: /backbone/body/layer3/layer3.1/bn1/Add_1): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Relu, node name: /backbone/body/layer3/layer3.1/relu/Relu): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Conv, node name: /backbone/body/layer3/layer3.1/conv2/Conv): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Mul, node name: /backbone/body/layer3/layer3.1/bn2/Mul_2): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Add, node name: /backbone/body/layer3/layer3.1/bn2/Add_1): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Relu, node name: /backbone/body/layer3/layer3.1/relu_1/Relu): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Conv, node name: /backbone/body/layer3/layer3.1/conv3/Conv): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Mul, node name: /backbone/body/layer3/layer3.1/bn3/Mul_2): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Add, node name: /backbone/body/layer3/layer3.1/bn3/Add_1): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Add, node name: /backbone/body/layer3/layer3.1/Add): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Relu, node name: /backbone/body/layer3/layer3.1/relu_2/Relu): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Conv, node name: /backbone/body/layer3/layer3.2/conv1/Conv): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Mul, node name: /backbone/body/layer3/layer3.2/bn1/Mul_2): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Add, node name: /backbone/body/layer3/layer3.2/bn1/Add_1): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Relu, node name: /backbone/body/layer3/layer3.2/relu/Relu): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Conv, node name: /backbone/body/layer3/layer3.2/conv2/Conv): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Mul, node name: /backbone/body/layer3/layer3.2/bn2/Mul_2): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Add, node name: /backbone/body/layer3/layer3.2/bn2/Add_1): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Relu, node name: /backbone/body/layer3/layer3.2/relu_1/Relu): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Conv, node name: /backbone/body/layer3/layer3.2/conv3/Conv): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Mul, node name: /backbone/body/layer3/layer3.2/bn3/Mul_2): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Add, node name: /backbone/body/layer3/layer3.2/bn3/Add_1): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Add, node name: /backbone/body/layer3/layer3.2/Add): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Relu, node name: /backbone/body/layer3/layer3.2/relu_2/Relu): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Conv, node name: /backbone/body/layer3/layer3.3/conv1/Conv): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Mul, node name: /backbone/body/layer3/layer3.3/bn1/Mul_2): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Add, node name: /backbone/body/layer3/layer3.3/bn1/Add_1): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Relu, node name: /backbone/body/layer3/layer3.3/relu/Relu): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Conv, node name: /backbone/body/layer3/layer3.3/conv2/Conv): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Mul, node name: /backbone/body/layer3/layer3.3/bn2/Mul_2): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Add, node name: /backbone/body/layer3/layer3.3/bn2/Add_1): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Relu, node name: /backbone/body/layer3/layer3.3/relu_1/Relu): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Conv, node name: /backbone/body/layer3/layer3.3/conv3/Conv): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Mul, node name: /backbone/body/layer3/layer3.3/bn3/Mul_2): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Add, node name: /backbone/body/layer3/layer3.3/bn3/Add_1): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Add, node name: /backbone/body/layer3/layer3.3/Add): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Relu, node name: /backbone/body/layer3/layer3.3/relu_2/Relu): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Conv, node name: /backbone/body/layer3/layer3.4/conv1/Conv): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Mul, node name: /backbone/body/layer3/layer3.4/bn1/Mul_2): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Add, node name: /backbone/body/layer3/layer3.4/bn1/Add_1): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Relu, node name: /backbone/body/layer3/layer3.4/relu/Relu): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Conv, node name: /backbone/body/layer3/layer3.4/conv2/Conv): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Mul, node name: /backbone/body/layer3/layer3.4/bn2/Mul_2): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Add, node name: /backbone/body/layer3/layer3.4/bn2/Add_1): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Relu, node name: /backbone/body/layer3/layer3.4/relu_1/Relu): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Conv, node name: /backbone/body/layer3/layer3.4/conv3/Conv): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Mul, node name: /backbone/body/layer3/layer3.4/bn3/Mul_2): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Add, node name: /backbone/body/layer3/layer3.4/bn3/Add_1): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Add, node name: /backbone/body/layer3/layer3.4/Add): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Relu, node name: /backbone/body/layer3/layer3.4/relu_2/Relu): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Conv, node name: /backbone/body/layer3/layer3.5/conv1/Conv): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Mul, node name: /backbone/body/layer3/layer3.5/bn1/Mul_2): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Add, node name: /backbone/body/layer3/layer3.5/bn1/Add_1): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Relu, node name: /backbone/body/layer3/layer3.5/relu/Relu): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Conv, node name: /backbone/body/layer3/layer3.5/conv2/Conv): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Mul, node name: /backbone/body/layer3/layer3.5/bn2/Mul_2): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Add, node name: /backbone/body/layer3/layer3.5/bn2/Add_1): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Relu, node name: /backbone/body/layer3/layer3.5/relu_1/Relu): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Conv, node name: /backbone/body/layer3/layer3.5/conv3/Conv): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Mul, node name: /backbone/body/layer3/layer3.5/bn3/Mul_2): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Add, node name: /backbone/body/layer3/layer3.5/bn3/Add_1): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Add, node name: /backbone/body/layer3/layer3.5/Add): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Relu, node name: /backbone/body/layer3/layer3.5/relu_2/Relu): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Conv, node name: /backbone/body/layer4/layer4.0/conv1/Conv): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Mul, node name: /backbone/body/layer4/layer4.0/bn1/Mul_2): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Add, node name: /backbone/body/layer4/layer4.0/bn1/Add_1): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Relu, node name: /backbone/body/layer4/layer4.0/relu/Relu): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Conv, node name: /backbone/body/layer4/layer4.0/conv2/Conv): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Mul, node name: /backbone/body/layer4/layer4.0/bn2/Mul_2): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Add, node name: /backbone/body/layer4/layer4.0/bn2/Add_1): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Relu, node name: /backbone/body/layer4/layer4.0/relu_1/Relu): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Conv, node name: /backbone/body/layer4/layer4.0/conv3/Conv): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Mul, node name: /backbone/body/layer4/layer4.0/bn3/Mul_2): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Add, node name: /backbone/body/layer4/layer4.0/bn3/Add_1): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Conv, node name: /backbone/body/layer4/layer4.0/downsample/downsample.0/Conv): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Mul, node name: /backbone/body/layer4/layer4.0/downsample/downsample.1/Mul_2): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Add, node name: /backbone/body/layer4/layer4.0/downsample/downsample.1/Add_1): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Add, node name: /backbone/body/layer4/layer4.0/Add): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Relu, node name: /backbone/body/layer4/layer4.0/relu_2/Relu): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Conv, node name: /backbone/body/layer4/layer4.1/conv1/Conv): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Mul, node name: /backbone/body/layer4/layer4.1/bn1/Mul_2): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Add, node name: /backbone/body/layer4/layer4.1/bn1/Add_1): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Relu, node name: /backbone/body/layer4/layer4.1/relu/Relu): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Conv, node name: /backbone/body/layer4/layer4.1/conv2/Conv): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Mul, node name: /backbone/body/layer4/layer4.1/bn2/Mul_2): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Add, node name: /backbone/body/layer4/layer4.1/bn2/Add_1): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Relu, node name: /backbone/body/layer4/layer4.1/relu_1/Relu): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Conv, node name: /backbone/body/layer4/layer4.1/conv3/Conv): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Mul, node name: /backbone/body/layer4/layer4.1/bn3/Mul_2): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Add, node name: /backbone/body/layer4/layer4.1/bn3/Add_1): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Add, node name: /backbone/body/layer4/layer4.1/Add): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Relu, node name: /backbone/body/layer4/layer4.1/relu_2/Relu): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Conv, node name: /backbone/body/layer4/layer4.2/conv1/Conv): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Mul, node name: /backbone/body/layer4/layer4.2/bn1/Mul_2): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Add, node name: /backbone/body/layer4/layer4.2/bn1/Add_1): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Relu, node name: /backbone/body/layer4/layer4.2/relu/Relu): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Conv, node name: /backbone/body/layer4/layer4.2/conv2/Conv): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Mul, node name: /backbone/body/layer4/layer4.2/bn2/Mul_2): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Add, node name: /backbone/body/layer4/layer4.2/bn2/Add_1): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Relu, node name: /backbone/body/layer4/layer4.2/relu_1/Relu): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Conv, node name: /backbone/body/layer4/layer4.2/conv3/Conv): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Mul, node name: /backbone/body/layer4/layer4.2/bn3/Mul_2): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Add, node name: /backbone/body/layer4/layer4.2/bn3/Add_1): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Add, node name: /backbone/body/layer4/layer4.2/Add): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Relu, node name: /backbone/body/layer4/layer4.2/relu_2/Relu): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Conv, node name: /backbone/fpn/inner_blocks.3/inner_blocks.3.0/Conv): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Conv, node name: /backbone/fpn/layer_blocks.3/layer_blocks.3.0/Conv): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Conv, node name: /backbone/fpn/inner_blocks.2/inner_blocks.2.0/Conv): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Resize, node name: /backbone/fpn/Resize): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Add, node name: /backbone/fpn/Add): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Conv, node name: /backbone/fpn/layer_blocks.2/layer_blocks.2.0/Conv): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Conv, node name: /backbone/fpn/inner_blocks.1/inner_blocks.1.0/Conv): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Resize, node name: /backbone/fpn/Resize_1): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Add, node name: /backbone/fpn/Add_1): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Conv, node name: /backbone/fpn/layer_blocks.1/layer_blocks.1.0/Conv): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Conv, node name: /backbone/fpn/inner_blocks.0/inner_blocks.0.0/Conv): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Resize, node name: /backbone/fpn/Resize_2): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Add, node name: /backbone/fpn/Add_2): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Conv, node name: /backbone/fpn/layer_blocks.0/layer_blocks.0.0/Conv): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:MaxPool, node name: /backbone/fpn/extra_blocks/MaxPool): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Conv, node name: /rpn/head/conv/conv.0/conv.0.0/Conv): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Relu, node name: /rpn/head/conv/conv.0/conv.0.1/Relu): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Conv, node name: /rpn/head/cls_logits/Conv): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Conv, node name: /rpn/head/bbox_pred/Conv): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Conv, node name: /rpn/head/conv/conv.0/conv.0.0_1/Conv): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Relu, node name: /rpn/head/conv/conv.0/conv.0.1_1/Relu): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Conv, node name: /rpn/head/cls_logits_1/Conv): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Conv, node name: /rpn/head/bbox_pred_1/Conv): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Conv, node name: /rpn/head/conv/conv.0/conv.0.0_2/Conv): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Relu, node name: /rpn/head/conv/conv.0/conv.0.1_2/Relu): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Conv, node name: /rpn/head/cls_logits_2/Conv): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Conv, node name: /rpn/head/bbox_pred_2/Conv): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Conv, node name: /rpn/head/conv/conv.0/conv.0.0_3/Conv): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Relu, node name: /rpn/head/conv/conv.0/conv.0.1_3/Relu): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Conv, node name: /rpn/head/cls_logits_3/Conv): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Conv, node name: /rpn/head/bbox_pred_3/Conv): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Conv, node name: /rpn/head/conv/conv.0/conv.0.0_4/Conv): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Relu, node name: /rpn/head/conv/conv.0/conv.0.1_4/Relu): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Conv, node name: /rpn/head/cls_logits_4/Conv): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Conv, node name: /rpn/head/bbox_pred_4/Conv): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Gather, node name: /rpn/Gather): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Gather, node name: /rpn/Gather_4): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Gather, node name: /rpn/Gather_8): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Gather, node name: /rpn/Gather_12): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Gather, node name: /rpn/Gather_16): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Reshape, node name: /rpn/Reshape): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Transpose, node name: /rpn/Transpose): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Reshape, node name: /rpn/Reshape_1): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Reshape, node name: /rpn/Reshape_2): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Transpose, node name: /rpn/Transpose_1): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Reshape, node name: /rpn/Reshape_3): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Reshape, node name: /rpn/Reshape_4): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Transpose, node name: /rpn/Transpose_2): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Reshape, node name: /rpn/Reshape_5): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Reshape, node name: /rpn/Reshape_6): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Transpose, node name: /rpn/Transpose_3): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Reshape, node name: /rpn/Reshape_7): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Reshape, node name: /rpn/Reshape_8): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Transpose, node name: /rpn/Transpose_4): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Reshape, node name: /rpn/Reshape_9): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Reshape, node name: /rpn/Reshape_10): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Transpose, node name: /rpn/Transpose_5): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Reshape, node name: /rpn/Reshape_11): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Reshape, node name: /rpn/Reshape_12): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Transpose, node name: /rpn/Transpose_6): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Reshape, node name: /rpn/Reshape_13): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Reshape, node name: /rpn/Reshape_14): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Transpose, node name: /rpn/Transpose_7): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Reshape, node name: /rpn/Reshape_15): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Reshape, node name: /rpn/Reshape_16): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Transpose, node name: /rpn/Transpose_8): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Reshape, node name: /rpn/Reshape_17): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Reshape, node name: /rpn/Reshape_18): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Transpose, node name: /rpn/Transpose_9): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Reshape, node name: /rpn/Reshape_19): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Concat, node name: /rpn/Concat_20): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Flatten, node name: /rpn/Flatten): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Concat, node name: /rpn/Concat_21): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Reshape, node name: /rpn/Reshape_20): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Reshape, node name: /rpn/Reshape_21): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Slice, node name: /rpn/Slice): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Div, node name: /rpn/Div_10): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Slice, node name: /rpn/Slice_1): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Div, node name: /rpn/Div_11): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Slice, node name: /rpn/Slice_2): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Div, node name: /rpn/Div_12): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Slice, node name: /rpn/Slice_3): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Div, node name: /rpn/Div_13): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Clip, node name: /rpn/Clip): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Clip, node name: /rpn/Clip_1): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Mul, node name: /rpn/Mul_12): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Add, node name: /rpn/Add_2): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Mul, node name: /rpn/Mul_13): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Add, node name: /rpn/Add_3): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Exp, node name: /rpn/Exp): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Mul, node name: /rpn/Mul_14): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Exp, node name: /rpn/Exp_1): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Mul, node name: /rpn/Mul_15): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Sub, node name: /rpn/Sub_2): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Sub, node name: /rpn/Sub_3): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Add, node name: /rpn/Add_4): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Add, node name: /rpn/Add_5): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Unsqueeze, node name: /rpn/Unsqueeze_102): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Unsqueeze, node name: /rpn/Unsqueeze_103): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Unsqueeze, node name: /rpn/Unsqueeze_104): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Unsqueeze, node name: /rpn/Unsqueeze_105): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Concat, node name: /rpn/Concat_24): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Flatten, node name: /rpn/Flatten_1): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Reshape, node name: /rpn/Reshape_22): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Reshape, node name: /rpn/Reshape_23): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Reshape, node name: /rpn/Reshape_24): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Slice, node name: /rpn/Slice_4): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Slice, node name: /rpn/Slice_5): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Slice, node name: /rpn/Slice_6): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Slice, node name: /rpn/Slice_7): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Slice, node name: /rpn/Slice_8): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:TopK, node name: /rpn/TopK): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:TopK, node name: /rpn/TopK_1): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Add, node name: /rpn/Add_12): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:TopK, node name: /rpn/TopK_2): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Add, node name: /rpn/Add_14): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:TopK, node name: /rpn/TopK_3): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Add, node name: /rpn/Add_16): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:TopK, node name: /rpn/TopK_4): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Add, node name: /rpn/Add_18): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Concat, node name: /rpn/Concat_38): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Flatten, node name: /rpn/Flatten_2): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Add, node name: /rpn/Add_19): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Gather, node name: /rpn/Gather_61): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Reshape, node name: /rpn/Reshape_31): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Reshape, node name: /rpn/Reshape_32): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Add, node name: /rpn/Add_20): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Flatten, node name: /rpn/Flatten_4): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Add, node name: /rpn/Add_21): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Gather, node name: /rpn/Gather_66): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Reshape, node name: /rpn/Reshape_35): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Reshape, node name: /rpn/Reshape_36): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Sigmoid, node name: /rpn/Sigmoid): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Split, node name: /rpn/Split): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Squeeze, node name: /rpn/Squeeze): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Split, node name: /rpn/Split_1): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Squeeze, node name: /rpn/Squeeze_1): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Slice, node name: /rpn/Slice_9): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Slice, node name: /rpn/Slice_10): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Max, node name: /rpn/Max): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Min, node name: /rpn/Min): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Max, node name: /rpn/Max_1): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Min, node name: /rpn/Min_1): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Unsqueeze, node name: /rpn/Unsqueeze_135): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Unsqueeze, node name: /rpn/Unsqueeze_136): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Concat, node name: /rpn/Concat_45): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Reshape, node name: /rpn/Reshape_37): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Gather, node name: /rpn/Gather_69): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Gather, node name: /rpn/Gather_70): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Sub, node name: /rpn/Sub_4): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Gather, node name: /rpn/Gather_71): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Gather, node name: /rpn/Gather_72): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Sub, node name: /rpn/Sub_5): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Gather, node name: /rpn/Gather_73): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Gather, node name: /rpn/Gather_74): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Gather, node name: /rpn/Gather_76): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Gather, node name: /rpn/Gather_77): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Gather, node name: /rpn/Gather_79): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Concat, node name: /roi_heads/box_roi_pool/Concat): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Slice, node name: /roi_heads/box_roi_pool/Slice): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Gather, node name: /roi_heads/box_roi_pool/Gather): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Gather, node name: /roi_heads/box_roi_pool/Gather_1): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Sub, node name: /roi_heads/box_roi_pool/Sub): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Gather, node name: /roi_heads/box_roi_pool/Gather_2): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Gather, node name: /roi_heads/box_roi_pool/Gather_3): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Sub, node name: /roi_heads/box_roi_pool/Sub_1): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Mul, node name: /roi_heads/box_roi_pool/Mul): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Concat, node name: /roi_heads/box_roi_pool/Concat_3): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Sqrt, node name: /roi_heads/box_roi_pool/Sqrt): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Div, node name: /roi_heads/box_roi_pool/Div): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Log, node name: /roi_heads/box_roi_pool/Log): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Div, node name: /roi_heads/box_roi_pool/Div_1): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Add, node name: /roi_heads/box_roi_pool/Add): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Add, node name: /roi_heads/box_roi_pool/Add_1): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Floor, node name: /roi_heads/box_roi_pool/Floor): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:Clip, node name: /roi_heads/box_roi_pool/Clip): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:RoiAlign, node name: /roi_heads/box_roi_pool/RoiAlign): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:RoiAlign, node name: /roi_heads/box_roi_pool/RoiAlign_1): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:RoiAlign, node name: /roi_heads/box_roi_pool/RoiAlign_2): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:RoiAlign, node name: /roi_heads/box_roi_pool/RoiAlign_3): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:RoiAlign, node name: /roi_heads/keypoint_roi_pool/RoiAlign): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:RoiAlign, node name: /roi_heads/keypoint_roi_pool/RoiAlign_1): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:RoiAlign, node name: /roi_heads/keypoint_roi_pool/RoiAlign_2): [TypeInferenceError] Input 0 expected to have type but instead is null
# (op_type:RoiAlign, node name: /roi_heads/keypoint_roi_pool/RoiAlign_3): [TypeInferenceError] Input 0 expected to have type but instead is null
#  (Triggered internally at ../torch/csrc/jit/serialization/export.cpp:1415.)
#   _C._check_onnx_proto(proto)

# %% [markdown]
# ### Simplify the ONNX Model

# %%
# Load the ONNX model from the onnx_file_name
onnx_model = onnx.load(onnx_file_path)

# Simplify the model
model_simp, check = simplify(onnx_model)

# Save the simplified model to the onnx_file_name
onnx.save(model_simp, onnx_file_path)

# %% [markdown]
# ## Performing Inference with ONNX Runtime

# %% [markdown]
# ### Create an Inference Session

# %%
# Load the model and create an InferenceSession
session = ort.InferenceSession(onnx_file_path, providers=['CPUExecutionProvider'])
# Out:
# 2024-01-29 14:42:55.674291468 [W:onnxruntime:, graph.cc:3553 CleanUnusedInitializersAndNodeArgs] Removing initializer '2802'. It is not used by any node and should be removed from the model.
# 2024-01-29 14:42:55.674305125 [W:onnxruntime:, graph.cc:3553 CleanUnusedInitializersAndNodeArgs] Removing initializer '2806'. It is not used by any node and should be removed from the model.
# 2024-01-29 14:42:55.674312663 [W:onnxruntime:, graph.cc:3553 CleanUnusedInitializersAndNodeArgs] Removing initializer '3372'. It is not used by any node and should be removed from the model.
# 2024-01-29 14:42:55.674314323 [W:onnxruntime:, graph.cc:3553 CleanUnusedInitializersAndNodeArgs] Removing initializer '3368'. It is not used by any node and should be removed from the model.
# 2024-01-29 14:42:55.674343317 [W:onnxruntime:, graph.cc:3553 CleanUnusedInitializersAndNodeArgs] Removing initializer '3763'. It is not used by any node and should be removed from the model.
# 2024-01-29 14:42:55.674345450 [W:onnxruntime:, graph.cc:3553 CleanUnusedInitializersAndNodeArgs] Removing initializer '3743'. It is not used by any node and should be removed from the model.
# 2024-01-29 14:42:55.674347141 [W:onnxruntime:, graph.cc:3553 CleanUnusedInitializersAndNodeArgs] Removing initializer '3739'. It is not used by any node and should be removed from the model.
# 2024-01-29 14:42:55.674348621 [W:onnxruntime:, graph.cc:3553 CleanUnusedInitializersAndNodeArgs] Removing initializer '3767'. It is not used by any node and should be removed from the model.
# 2024-01-29 14:42:55.674350583 [W:onnxruntime:, graph.cc:3553 CleanUnusedInitializersAndNodeArgs] Removing initializer '3777'. It is not used by any node and should be removed from the model.
# 2024-01-29 14:42:55.682623294 [W:onnxruntime:, graph.cc:3553 CleanUnusedInitializersAndNodeArgs] Removing initializer '2807'. It is not used by any node and should be removed from the model.
# 2024-01-29 14:42:55.682633734 [W:onnxruntime:, graph.cc:3553 CleanUnusedInitializersAndNodeArgs] Removing initializer '2803'. It is not used by any node and should be removed from the model.
# 2024-01-29 14:42:55.682635777 [W:onnxruntime:, graph.cc:3553 CleanUnusedInitializersAndNodeArgs] Removing initializer '2804'. It is not used by any node and should be removed from the model.
# 2024-01-29 14:42:55.682637245 [W:onnxruntime:, graph.cc:3553 CleanUnusedInitializersAndNodeArgs] Removing initializer '2805'. It is not used by any node and should be removed from the model.
# 2024-01-29 14:42:55.682642627 [W:onnxruntime:, graph.cc:3553 CleanUnusedInitializersAndNodeArgs] Removing initializer '3369'. It is not used by any node and should be removed from the model.
# 2024-01-29 14:42:55.682644184 [W:onnxruntime:, graph.cc:3553 CleanUnusedInitializersAndNodeArgs] Removing initializer '3370'. It is not used by any node and should be removed from the model.
# 2024-01-29 14:42:55.682645595 [W:onnxruntime:, graph.cc:3553 CleanUnusedInitializersAndNodeArgs] Removing initializer '3371'. It is not used by any node and should be removed from the model.
# 2024-01-29 14:42:55.682647121 [W:onnxruntime:, graph.cc:3553 CleanUnusedInitializersAndNodeArgs] Removing initializer '3373'. It is not used by any node and should be removed from the model.
# 2024-01-29 14:42:55.682656043 [W:onnxruntime:, graph.cc:3553 CleanUnusedInitializersAndNodeArgs] Removing initializer '3744'. It is not used by any node and should be removed from the model.
# 2024-01-29 14:42:55.682657518 [W:onnxruntime:, graph.cc:3553 CleanUnusedInitializersAndNodeArgs] Removing initializer '3768'. It is not used by any node and should be removed from the model.
# 2024-01-29 14:42:55.682659105 [W:onnxruntime:, graph.cc:3553 CleanUnusedInitializersAndNodeArgs] Removing initializer '3765'. It is not used by any node and should be removed from the model.
# 2024-01-29 14:42:55.682660575 [W:onnxruntime:, graph.cc:3553 CleanUnusedInitializersAndNodeArgs] Removing initializer '3766'. It is not used by any node and should be removed from the model.
# 2024-01-29 14:42:55.682661949 [W:onnxruntime:, graph.cc:3553 CleanUnusedInitializersAndNodeArgs] Removing initializer '3740'. It is not used by any node and should be removed from the model.
# 2024-01-29 14:42:55.682663366 [W:onnxruntime:, graph.cc:3553 CleanUnusedInitializersAndNodeArgs] Removing initializer '3742'. It is not used by any node and should be removed from the model.
# 2024-01-29 14:42:55.682664943 [W:onnxruntime:, graph.cc:3553 CleanUnusedInitializersAndNodeArgs] Removing initializer '3741'. It is not used by any node and should be removed from the model.
# 2024-01-29 14:42:55.682666622 [W:onnxruntime:, graph.cc:3553 CleanUnusedInitializersAndNodeArgs] Removing initializer '3764'. It is not used by any node and should be removed from the model.

# %% [markdown]
# ### Define Utility Functions

# %%
def draw_keypoints_pil(image, keypoints, labels, colors, radius:int=5):
        
    # Create a copy of the image
    annotated_image = image.copy()

    # Create an ImageDraw object for drawing on the image
    draw = ImageDraw.Draw(annotated_image)

    # Loop through the bounding boxes and labels in the 'annotation' DataFrame
    for i in range(len(labels)):
        # Get the key point coordinates
        x, y = keypoints[i]

        # Draw a circle
        draw.ellipse((x - radius, y - radius, x + radius, y + radius), fill=colors[i])
        
    return annotated_image

# %% [markdown]
# ### Select a Test Image

# %%
test_img_name = "pexels-2769554-man-doing-rock-and-roll-sign.jpg"
test_img_url = f"https://huggingface.co/datasets/cj-mills/pexel-hand-gesture-test-images/resolve/main/{test_img_name}"

download_file(test_img_url, './', False)

test_img = Image.open(test_img_name)
display(test_img)

pd.Series({
    "Test Image Size:": test_img.size, 
}).to_frame().style.hide(axis='columns')
# Out:
# The file ./pexels-2769554-man-doing-rock-and-roll-sign.jpg already exists and overwrite is set to False.
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x960>
# <style type="text/css">
# </style>
# <table id="T_e22ce">
#   <thead>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e22ce_level0_row0" class="row_heading level0 row0" >Test Image Size:</th>
#       <td id="T_e22ce_row0_col0" class="data row0 col0" >(640, 960)</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Prepare the Test Image

# %%
# Set test image size
test_sz = 512

## Resize the test image
input_img = resize_img(test_img, target_sz=test_sz, divisor=1)

# Calculate the scale between the source image and the resized image
min_img_scale = min(test_img.size) / min(input_img.size)

display(input_img)

# Print the prediction data as a Pandas DataFrame for easy formatting
pd.Series({
    "Source Image Size:": test_img.size,
    "Input Dims:": input_img.size,
    "Min Image Scale:": min_img_scale,
    "Input Image Size:": input_img.size
}).to_frame().style.hide(axis='columns')
# Out:
# <PIL.Image.Image image mode=RGB size=512x768>
# <style type="text/css">
# </style>
# <table id="T_391ab">
#   <thead>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_391ab_level0_row0" class="row_heading level0 row0" >Source Image Size:</th>
#       <td id="T_391ab_row0_col0" class="data row0 col0" >(640, 960)</td>
#     </tr>
#     <tr>
#       <th id="T_391ab_level0_row1" class="row_heading level0 row1" >Input Dims:</th>
#       <td id="T_391ab_row1_col0" class="data row1 col0" >(512, 768)</td>
#     </tr>
#     <tr>
#       <th id="T_391ab_level0_row2" class="row_heading level0 row2" >Min Image Scale:</th>
#       <td id="T_391ab_row2_col0" class="data row2 col0" >1.250000</td>
#     </tr>
#     <tr>
#       <th id="T_391ab_level0_row3" class="row_heading level0 row3" >Input Image Size:</th>
#       <td id="T_391ab_row3_col0" class="data row3 col0" >(512, 768)</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Prepare the Input Tensor

# %%
# Convert the input image to NumPy format
input_tensor_np = np.array(input_img, dtype=np.float32).transpose((2, 0, 1))[None]/255

# %% [markdown]
# ### Compute the Predictions

# %%
# Run inference
model_output = session.run(None, {"input": input_tensor_np})

# Set the confidence threshold
conf_threshold = 0.8

# Filter the output based on the confidence threshold
scores_mask = model_output[2] > conf_threshold

# Extract and scale the predicted keypoints
predicted_keypoints = (model_output[3][scores_mask])[:,:,:-1].reshape(-1,2)*min_img_scale
predicted_keypoints

labels=class_names*sum(scores_mask).item()

draw_keypoints_pil(test_img, 
                predicted_keypoints, 
                labels=labels,
                colors=[int_colors[i] for i in [class_names.index(label) for label in labels]],
               )
# Out:
# <PIL.Image.Image image mode=RGB size=640x960>

# %%
assert False

# %%
import openvino as ov

# %%
# Set a filename for the OpenVINO model
ov_file_path = f"{checkpoint_dir}/{Path(onnx_file_path).stem}.xml"

# %%
ov_model = ov.convert_model(onnx_file_path)
ov.save_model(ov_model, ov_file_path)
